# %%
## 데이터 셋 다운로드 받기
# !kaggle datasets download -d forgemaster/steam-reviews-dataset

## 파일 옮기고 압축풀기
# !mkdir -p ~/project/TIL/AI_study/dataset/steam
# !mv steam-reviews-dataset.zip ~/project/TIL/AI_study/dataset/zips/steam-reviews-dataset.zip
# !unzip ~/project/TIL/AI_study/dataset/zips/steam-reviews-dataset.zip -d ~/project/TIL/AI_study/dataset/steam

# %%
from imutils.paths import list_files
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
DATASET_PATH = '/home/jovyan/project/TIL/AI_study/dataset/steam'

# %%
csv_files   = sorted(list_files(DATASET_PATH))
data_frames = pd.read_csv(csv_files[0])

# %%
data_frames[500:200000].tail()
# Out:
#                   steamid  appid  voted_up  votes_up  votes_funny  \
# 199995  76561199122108926    550      True         0            0
# 199996  76561198388043384    550      True         0            0
# 199997  76561198406194130    550      True         0            0
# 199998  76561199090348127    550      True         0            1
# 199999  76561199019193079    550      True         0            0
#
#         weighted_vote_score  playtime_forever  playtime_at_review  \
# 199995                  0.0               160                  48
# 199996                  0.0               502                 216
# 199997                  0.0              1124                 368
# 199998                  0.0                94                  40
# 199999                  0.0              1832                 496
#
#         num_games_owned  num_reviews  \
# 199995               31            2
# 199996                7            1
# 199997                5            4
# ...
