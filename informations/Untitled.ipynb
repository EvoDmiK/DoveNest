# %%
from bs4 import BeautifulSoup as bs
import requests as req

# %%
res = req.get('https://www.inven.co.kr/webzine/schedule/')

# %%
soup = bs(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=EDGE" http-equiv="X-UA-Compatible"/>
# <meta content="게임,온라인게임,모바일게임,콘솔게임,VR,CBT,OBT,리뷰,게임 정보,게임 공략,최신 게임,인벤,INVEN,게임일정" name="keywords"/>
# <meta content="게임일정" name="description"/>
# <meta content="3a508505e9bf09f6b8b7abe782e34f3cc895eb65" name="naver-site-verification"/>
# <meta content="webzine" name="inven-site"/>
# <meta content="웹진" name="inven-sitename"/>
# <meta content="게임 출시/서비스 일정" property="og:title"/>
# <meta content="lIEHCJnG/fRc4u0jvDLJsg==" id="inven-verification" name="inven-verification"/>
# <title>게임 출시/서비스 일정 - 인벤</title>
# <link href="https://www.inven.co.kr/common/lib/style/dist/quicklink.css?v=220602ca" rel="stylesheet" type="text/css"/>
# <link href="https://www.inven.co.kr/common/lib/style/ad.css?v=220124aa" rel="stylesheet" type="text/css"/>
# ...
