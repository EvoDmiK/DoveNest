# %%
from bs4 import BeautifulSoup as bs
import requests as req
import json

# %%
res   = req.get('https://store.playstation.com/es-EN/search/game')
soup  = bs(res.text, 'html.parser')
datas = soup.select('div#__next > #main > section > div > ul > li > div > a')

# %%
for data in datas:
    print(json.loads(data['data-telemetry-meta'])['name'])
# Out:
# Madden NFL 22 Cover Athlete Content
# The Game of Life 2
# Highway Driving
# The Game of Life 2 - Sweet Haven World
# MONOPOLY® Madness
# Space Explore
# War Games Sonya Blade
# Friday the 13th: The Game
# Sherlock Holmes Chapter One - Clergyman Cassock
# METAL GEAR ONLINE GAME DATA Ver 1.10
# Sherlock Holmes Chapter One - Plague Doctor Pack
# Madden NFL 22 PS4™
# Red Dead Redemption 2
# JUMANJI: The Video Game
# Grand Theft Auto V: Premium Edition & Whale Shark Card Bundle
# Crazy Athletics - Summer Sports & Games
# Apex Legends™: PlayStation®Plus Play Pack
# America’s Greatest Game Shows: Wheel of Fortune® & Jeopardy!
# Empire of Sin
# Yurukill: The Calumniation Games Demo
# Sherlock Holmes Chapter One - Clergyman Cassock
# After the Fall® - Exclusive “Ultimate Buster”  Weapon Skin
# Necromunda: Hired Gun - Hellhound Pack
# Sherlock Holmes Chapter One - Detective Pack

# %%
json.loads(datas[5]['data-telemetry-meta'])
# Out:
# {'id': 'UP3362-CUSA28159_00-3300943839198553',
#  'index': 5,
#  'name': 'Space Explore',
#  'price': '$9.99',
#  'titleId': 'CUSA28159_00',
#  'searchTerm': 'game'}

# %%
datas
# Out:
# [<a aria-label="" class="psw-link psw-content-link" data-qa="" data-telemetry-meta='{"id":"UP1001-CUSA05697_00-ASIA000000000000","index":0,"name":"Carnival Games® VR (영어판)","price":"24,500원","titleId":"CUSA05697_00","searchTerm":"game"}' data-track="web:store:product-tile" data-track-click="web:store:product-tile" data-track-content="web:store:product-tile" href="/ko-kr/product/UP1001-CUSA05697_00-ASIA000000000000" id="" rel="noopener noreferrer" type=""><div class="psw-product-tile psw-interactive-root" data-qa="search#productTile0"><div class="psw-ally-indicator psw-ally-indicator-gap-1 psw-show-on-hover psw-b-0 psw-game-art psw-fill psw-l-anchor" data-qa="search#productTile0#game-art"><div class="psw-game-art__container psw-l-anchor-top-left psw-l-top-left psw-fill psw-r-2 psw-clip"><span class="psw-illustration psw-illustration--default-product-image default-product-img" data-qa=""><svg aria-hidden="true" focusable="false"><title></title><use href="#ps-illustration:default-produc
# ...
