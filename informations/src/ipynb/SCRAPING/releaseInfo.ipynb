# %%
from bs4 import BeautifulSoup as bs
import requests as req
import json
import os

# %%
BASE_URL    = 'https://www.nintendo.co.kr'
SALE_URL    = f'www.store.nintendo.co.kr/games/sale'
RELEASE_URL = f'{BASE_URL}/software/release/'

# %%
def preprocessing(string, dtype = 'date'):
    
    string = string.replace('  ', '')
    string = string.replace('(', '').replace(')', '')
    string = string.replace('\r\n', '')
    
    return string


def get_crawl(URL):
    res = req.get(URL).text
    return bs(res, 'html.parser')

# %%
soup_rel = get_crawl(RELEASE_URL)
releases = soup_rel.select('.release-soft')[0].select('li')

# %%
for release in releases:
    thumbnail = release.select('img')[0]['src']
    thumbnail = f'{BASE_URL}{thumbnail}'
    
    title     = preprocessing(release.select('.device-switch')[0].text)
    rel_date  = preprocessing(release.select('.rel-date')[0].text)
    developer = preprocessing(release.select('.rel-maker')[0].text)
    
    rel_date  = rel_date if rel_date != '\n' else '미정'
    print(f'[title]      : {title}')
    print(f'[rel date]   : {rel_date}')
    print(f'[thumbnail]  : {thumbnail}')
    print(f'[develpoper] : {developer}\n')
# Out:
# [title]      : Fallen Knight
# [rel date]   : 2023.05.11
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3330/de41c1dc922eac300da83d3d959212e3.jpg
# [develpoper] : Phoenixx
#
# [title]      : 엘리멘탈 워 2 Elemental War 2
# [rel date]   : 2023.05.11
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3231/840ccb5e4fbfe89e487a6bfe0f53d70b.jpg
# [develpoper] : Clockwork Origins
#
# [title]      : 젤다의 전설 티어스 오브 더 킹덤
# [rel date]   : 2023.05.12
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3078/694093fa18a6d6745b64098c755142ff.jpg
# [develpoper] : 한국닌텐도
#
# [title]      : 레고® 2K 드라이브
# [rel date]   : 2023.05.19
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3332/23c81bb2d6268d45f3487d378edce12a.jpg
# [develpoper] : 2K Games
#
# [title]      : Farming Simulator 23: Nintendo Switch™ Edition
# [rel date]   : 2023.05.23
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3137/96699ed38095046909db6ebb27919dd3.jpg
# [develpoper] : GIANTS Software
#
# [title]      : 컬러링 픽셀: 콜렉션 3
# [rel date]   : 2023.05.25
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3329/1f5ca7354b5cc3a58a6c3f6a3239149e.jpg
# [develpoper] : ToastieLabs
#
# [title]      : 마계전기 디스가이아7
# [rel date]   : 2023.05.25
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3331/47b0e63e748d0aca4d7a6a7799a4b9a6.jpg
# [develpoper] : NIHONICHI
#
# [title]      : 이스 메모와르 -펠가나의 맹세-
# [rel date]   : 2023.05.25
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/3292/8fdb02dce43fa99fea9bc1d916d1d3bd.jpg
# [develpoper] : Clouded Leopard Entertainment
#
# [title]      : 피트니스 러너
# [rel date]   : 2023.05.26
# [thumbnail]  : https://www.nintendo.co.kr/front_images/sw/release/